# %% [markdown]
# # Sources
#
# |Description|link|
# |-|-|
# |Basics and prerequisites| https://developers.google.com/custom-search/v1/introduction|
# |Docs and Data-format| https://developers.google.com/custom-search/v1/overview|

# %% [markdown]
# Wir bekommen 100 queries gratis am Tag

# %%
# HIDE API KEY IN VENV

import os
from dotenv import load_dotenv #pip install python-dotenv
load_dotenv()
print(f"key:\t{os.getenv("KEY")}\nid:\t{os.getenv("ID")}")
# Out:
# key:	AIzaSyD86XHwx-tgBrhPElpXBTKXARMZ7OCmxrQ
# id:	21f1988696318429c

# %%
import requests

# %%
def search(query):
    url = "https://www.googleapis.com/customsearch/v1"
    params = dict(q = query, key = os.getenv("KEY"), cx = os.getenv("ID"),    # required params
                  dateRestrict = "d1") # additional parameters
    
    response = requests.get(url,params=params,verify=False)
    print(f"{response.status_code} {response.reason}")
    return response.json().get("items",[])

# %%
query = "Trevelin Queen"
result = search(query)
# Out:
# c:\Users\ms216u.MUCLVAD1\OneDrive - Linde Group\Studium\Semester 5\NLP\Projekt\venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.googleapis.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 200 OK

# %%
result
# Out:
# [{'kind': 'customsearch#result',
#   'title': 'Adam Young (@youngpbp) / X',
#   'htmlTitle': 'Adam Young (@youngpbp) / X',
#   'link': 'https://twitter.com/youngpbp',
#   'displayLink': 'twitter.com',
#   'snippet': '14 hours ago ... Trev Queen — game ball! ❤️. @NMStateMBB. || #ProAggies. Embedded video. 0 ... Trevelin Queen from deep and the Magic are within 10 Less than 7 minutes\xa0...',
#   'htmlSnippet': '14 hours ago <b>...</b> Trev Queen — game ball! ❤️. @NMStateMBB. || #ProAggies. Embedded video. 0 ... <b>Trevelin Queen</b> from deep and the Magic are within 10 Less than 7 minutes&nbsp;...',
#   'formattedUrl': 'https://twitter.com/youngpbp',
#   'htmlFormattedUrl': 'https://twitter.com/youngpbp',
#   'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRXAGzJZ2zAFXdx8-l9A8RTerRMBpPiQs7EQ4fDi7TmafyWQH_up0KHN68&s',
#      'width': '200',
#      'height': '200'}],
# ...

# %%
len(result)
# Out:
# 10

# %%
[item["link"] for item in result]
# Out:
# ['https://twitter.com/youngpbp',
#  'https://www.instagram.com/d.mcghee2/?hl=en',
#  'https://www.nba.com/stats/events?CFID=&CFPARAMS=&ContextMeasure=PTS_PAINT&GameID=0022400377&PlayerID=1630243&Season=2024-25&SeasonType=Regular%20Season&TeamID=1610612753&flag=1&sct=plot&section=game',
#  'https://www.threads.net/@bryce_bachelder',
#  'https://osceola.gleague.nba.com/news/osceola-magic-fall-in-back-and-forth-match-against-college-park-skyhawks',
#  'https://www.threads.net/@trevajct/post/DD6b1lsP7uM',
#  'https://www.lineupexperts.com/basketball/who-to-start-analysis?start=antonio-reeves_or_trevelin-queen&interval=CurrentWeek',
#  'http://www.msn.com/en-ca/sports/nba/magic-tie-franchise-record-with-25-point-comeback-in-121-114-win-over-heat/ar-AA1wixsx?apiversion=v2&noservercache=1&domshim=1&renderwebcomponents=1&wcseo=1&batchservertelemetry=1&noservertelemetry=1',
#  'https://basketball.razzball.com/basketball-teams/orlando-magic/',
# ...
