# %% [markdown]
# # Sources
#
# |Description|link|
# |-|-|
# |Basics and prerequisites| https://developers.google.com/custom-search/v1/introduction|
# |Docs and Data-format| https://developers.google.com/custom-search/v1/overview|

# %% [markdown]
# Wir bekommen 100 queries gratis am Tag

# %%
# HIDE API KEY IN VENV

import os
from dotenv import load_dotenv #pip install python-dotenv
path = os.path.join(os.getcwd(),"..","etc",".env")
load_dotenv(path)
print(path)
print(f"key:\t{os.getenv("GOOGLE_KEY")}\nid:\t{os.getenv("GOOGLE_ID")}")
# Out:
# c:\Users\ms216u.MUCLVAD1\OneDrive - Linde Group\Studium\Semester 5\NLP\Projekt\explorations\..\etc\.env
# key:	AIzaSyD86XHwx-tgBrhPElpXBTKXARMZ7OCmxrQ
# id:	21f1988696318429c

# %%
import requests

# %%
def search(query):
    url = "https://www.googleapis.com/customsearch/v1"
    params = dict(q = query, key = os.getenv("GOOGLE_KEY"), cx = os.getenv("GOOGLE_ID"),    # required params
                  dateRestrict = "d1") # additional parameters
    
    response = requests.get(url,params=params,verify=False)
    print(f"{response.status_code} {response.reason}")
    return response.json().get("items",[])

# %%
query = "Trevelin Queen"
result = search(query)
# Out:
# c:\Users\ms216u.MUCLVAD1\OneDrive - Linde Group\Studium\Semester 5\NLP\Projekt\venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.googleapis.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 200 OK

# %%
result
# Out:
# [{'kind': 'customsearch#result',
#   'title': 'Trevelin Queen - Orlando Magic Shooting Guard - ESPN',
#   'htmlTitle': '<b>Trevelin Queen</b> - Orlando Magic Shooting Guard - ESPN',
#   'link': 'https://www.espn.com/nba/player/_/id/4409222/trevelin-queen',
#   'displayLink': 'www.espn.com',
#   'snippet': '14 hours ago ... View the profile of Orlando Magic Shooting Guard Trevelin Queen on ESPN. Get the latest news, live stats and game highlights.',
#   'htmlSnippet': '14 hours ago <b>...</b> View the profile of Orlando Magic Shooting Guard <b>Trevelin Queen</b> on ESPN. Get the latest news, live stats and game highlights.',
#   'formattedUrl': 'https://www.espn.com/nba/player/_/id/4409222/trevelin-queen',
#   'htmlFormattedUrl': 'https://www.espn.com/nba/player/_/id/4409222/<b>trevelin</b>-<b>queen</b>',
#   'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTLg6BrxkVUx6PYntvIAX0Gow16W30GvIffzKqF5YC6FeuUCepBYZ3oJbU&s',
#      'width': '263',
# ...

# %%
len(result)
# Out:
# 10

# %%
[item["link"] for item in result]
# Out:
# ['https://www.espn.com/nba/player/_/id/4409222/trevelin-queen',
#  'https://www.espn.com.au/nba/player/_/id/4409222/trevelin-queen',
#  'https://www.instagram.com/orlandomagichq/p/DETR4KCR2ki/',
#  'https://x.com/Underdog__NBA/status/1874584803351085146',
#  'https://www.cbssports.com/fantasy/basketball/news/magics-trevelin-queen-out-with-illness-wednesday/',
#  'https://knupsports.com/trevelin-queen-questionable-for-magic-with-illness/',
#  'https://www.rotowire.com/basketball/headlines/trevelin-queen-injury-out-with-illness-wednesday-475299',
#  'https://knupsports.com/trevelin-queen-out-for-magic-due-to-illness/',
#  'https://www.footboom1.com/en/news/basketball/2246753-magic-s-trevelin-queen-to-miss-wednesday-s-clash-with-pistons',
#  'https://twitter.com/Underdog__NBA/status/1874584253532353000']

# %%
import os
import requests
from dotenv import load_dotenv #pip install python-dotenv


def google_search(query:str)->list[str]:
    '''Returns a list of links to results from the last 24hrs'''

    params = dict(q = query, key = os.getenv("GOOGLE_KEY"), cx = os.getenv("GOOGLE_ID"),    # required params
                dateRestrict = "d1") # additional parameters
    
    response = requests.get("https://www.googleapis.com/customsearch/v1",params=params,verify=False)

    if response.status_code != 200:
        print(f"{response.status_code} {response.reason}")
        raise EnvironmentError("Make sure that the google credentials in your environment are correct and that you have quotas left for your query.")
    
    result = response.json().get("items",[])
    return [item["link"] for item in result]
load_dotenv(os.path.join(os.getcwd(),"etc",".env")) # load .env file into memory
google_search("Recent performance of Lebron James in the NBA")
# Out:
# c:\Users\ms216u.MUCLVAD1\OneDrive - Linde Group\Studium\Semester 5\NLP\Projekt\venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.googleapis.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# ['https://www.espn.com/nba/team/_/name/lal/los-angeles-lakers',
#  'https://digital-dev.lib.calpoly.edu/ednews-tech/is-lebron-james-thriving-understanding-nba-greats-longevity-and-impact.html',
#  'https://www.espn.com/mens-college-basketball/story/_/id/43250299/lebron-james-youngest-son-bryce-james-commits-arizona',
#  'https://www.numberfire.com/nba/players/lebron-james',
#  'https://www.kold.com/2025/01/01/lebron-james-son-commits-play-arizona-wildcats/',
#  'https://athlonsports.com/nba/los-angeles-lakers/austin-reaves-delivers-career-best-performance',
# ...
